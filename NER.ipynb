# %%
import tensorflow as tf

# %%
# !pip install torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 6.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 4.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install numpy==1.23.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ...

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 4.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 7.6 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.9 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 8.4 MB/s eta 0:00:0000:0100:01m
# ...
#   Using cached streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.9 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 9.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pandas as pd
data = pd.read_csv("ner_dataset.csv",encoding="latin1" )

# %%
data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
data = data.fillna(method='ffill')

# %%
data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1  Sentence: 1             of   IN   O
# 2  Sentence: 1  demonstrators  NNS   O
# 3  Sentence: 1           have  VBP   O
# 4  Sentence: 1        marched  VBN   O

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data['Sentence #'] = LabelEncoder().fit_transform(data['Sentence #'])

# %%
data.head(30)
# Out:
#     Sentence #           Word  POS    Tag
# 0            0      Thousands  NNS      O
# 1            0             of   IN      O
# 2            0  demonstrators  NNS      O
# 3            0           have  VBP      O
# 4            0        marched  VBN      O
# 5            0        through   IN      O
# 6            0         London  NNP  B-geo
# 7            0             to   TO      O
# 8            0        protest   VB      O
# 9            0            the   DT      O
# 10           0            war   NN      O
# 11           0             in   IN      O
# 12           0           Iraq  NNP  B-geo
# 13           0            and   CC      O
# 14           0         demand   VB      O
# 15           0            the   DT      O
# 16           0     withdrawal   NN      O
# 17           0             of   IN      O
# 18           0        British   JJ  B-gpe
# 19           0         troops  NNS      O
# 20           0           from   IN      O
# ...

# %%
data['Tag'] = data['Tag'].apply(str.upper)

# %%
data.head(30)
# Out:
#     Sentence #           Word  POS    Tag
# 0            0      Thousands  NNS      O
# 1            0             of   IN      O
# 2            0  demonstrators  NNS      O
# 3            0           have  VBP      O
# 4            0        marched  VBN      O
# 5            0        through   IN      O
# 6            0         London  NNP  B-GEO
# 7            0             to   TO      O
# 8            0        protest   VB      O
# 9            0            the   DT      O
# 10           0            war   NN      O
# 11           0             in   IN      O
# 12           0           Iraq  NNP  B-GEO
# 13           0            and   CC      O
# 14           0         demand   VB      O
# 15           0            the   DT      O
# 16           0     withdrawal   NN      O
# 17           0             of   IN      O
# 18           0        British   JJ  B-GPE
# 19           0         troops  NNS      O
# 20           0           from   IN      O
# ...

# %%
data.rename(columns={'Sentence #':'sentence_id','Word':'word','Tag':'label'}, inplace=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(data[['sentence_id','word']],data['label'],test_size=0.2)

# %%
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["word"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["word"],"labels":y_test})

# %%
train_data[train_data['sentence_id']==0]
# Out:
#     sentence_id          words labels
# 14            0         demand      O
# 1             0             of      O
# 12            0           Iraq  B-GEO
# 9             0            the      O
# 8             0        protest      O
# 20            0           from      O
# 0             0      Thousands      O
# 2             0  demonstrators      O
# 6             0         London  B-GEO
# 16            0     withdrawal      O
# 7             0             to      O
# 22            0        country      O
# 15            0            the      O
# 19            0         troops      O
# 23            0              .      O
# 3             0           have      O
# 13            0            and      O
# 10            0            war      O
# 11            0             in      O

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label = data['label'].unique().tolist()

# %%
args = NERArgs()
args.num_train_epochs = 1
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model_base = NERModel('bert', 'bert-base-cased', use_cuda=False, args=modelbase_args)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
modelbase_args = NERArgs()

# %%
prediction, model_output = model_base.predict(["Publicis is an esteemed of United States of America. Indians like it a lot."])
prediction
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [[{'Publicis': 'B-GEO'},
#   {'is': 'B-GEO'},
#   {'an': 'B-GEO'},
#   {'esteemed': 'B-GEO'},
#   {'of': 'B-GEO'},
#   {'United': 'B-GEO'},
#   {'States': 'B-GEO'},
#   {'of': 'B-LOC'},
#   {'America.': 'B-GEO'},
#   {'Indians': 'B-GEO'},
#   {'like': 'B-GEO'},
#   {'it': 'B-GEO'},
#   {'a': 'B-LOC'},
#   {'lot.': 'B-GEO'}]]

# %%
model = NERModel('bert', 'bert-base-cased',labels=label,args =args, use_cuda=False)
# Out:
# ...
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Epoch 0 of 1:   0%|          | 0/1499 [00:00<?, ?it/s]
# (1499, 0.19448173903251903)

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Evaluation:   0%|          | 0/1459 [00:00<?, ?it/s]

# %%
result
# Out:
# {'eval_loss': 0.17076099728444122,
#  'precision': 0.8275682252737702,
#  'recall': 0.7644263190006744,
#  'f1_score': 0.794745100657697}

# %%
prediction, model_output = model.predict(["Publicis Sapient is an esteemed of United States of America. Indians like it a lot."])
prediction
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [[{'Publicis': 'I-ORG'},
#   {'Sapient': 'O'},
#   {'is': 'O'},
#   {'an': 'O'},
#   {'esteemed': 'O'},
#   {'of': 'O'},
#   {'United': 'B-GEO'},
#   {'States': 'I-GEO'},
#   {'of': 'O'},
#   {'America.': 'B-GEO'},
#   {'Indians': 'B-GPE'},
#   {'like': 'O'},
#   {'it': 'O'},
#   {'a': 'O'},
#   {'lot.': 'O'}]]
